# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
prod_df = pd.read_table('./products.tsv')
rev_df = pd.read_table('./reviews.tsv')
prod_df.head()
# Out:
#    product_id    product_name                              product_model  \
# 0      103205        Dr. Puri  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
# 1      101774         HIGUARD  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
# 2      102455       Now Foods                                  Face Mask
# 3      100840  YJ Corporation  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
# 4      100839    One Fine Day  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
#
#      product_features prod_features1 prod_features2 prod_features3  \
# 0        20 Masks, ,        20 Masks            NaN            NaN
# 1          1 Mask, ,          1 Mask            NaN            NaN
# 2   Grey, S-M, 1 Mask           Grey            S-M         1 Mask
# 3  for Kids, 1 Mask,        for Kids         1 Mask            NaN
# 4          1 Mask, ,          1 Mask            NaN            NaN
#
#    product_price price_currency       product_availability  \
# 0           2.95            AUD  http://schema.org/InStock
# 1           2.95            AUD  http://schema.org/InStock
# 2           2.95            AUD  http://schema.org/InStock
# 3           3.93            AUD  http://schema.org/InStock
# 4           4.49            AUD  http://schema.org/InStock
#
#                                          product_url  \
# 0  https://au.iherb.com/pr/Hwipure-Disposable-KF9...
# 1  https://au.iherb.com/pr/HIGUARD-Disposable-KF9...
# 2  https://au.iherb.com/pr/Now-Foods-Face-Mask-Gr...
# 3  https://au.iherb.com/pr/YJ-Corporation-Disposa...
# 4  https://au.iherb.com/pr/One-Fine-Day-Disposabl...
#
#                                      source_url
# 0  https://au.iherb.com/c/protective-face-masks
# 1  https://au.iherb.com/c/protective-face-masks
# 2  https://au.iherb.com/c/protective-face-masks
# 3  https://au.iherb.com/c/protective-face-masks
# 4  https://au.iherb.com/c/protective-face-masks

# %%
# Most popular brand
z = rev_df.productId.value_counts()
z[z.index[0]]
# Out:
# 658

# %%
prod_name = list()
popularity = list()
for i in range(0,len(z.index)):
    prod_name.append(prod_df.iloc[prod_df[prod_df.product_id == z.index[i]].index[0]].product_name+" "
    +prod_df.iloc[prod_df[prod_df.product_id == z.index[i]].index[0]].product_model)
    popularity.append(z[z.index[i]])

# %%
plt.barh(prod_name,popularity)
# Out:
# <BarContainer object of 27 artists>

# %%
prod_df[['Brand', 'Type']] = prod_df.product_name.str.split(", ", expand = True).iloc[:,0:2]
prod_df.product_name.str.split(', ',expand=True).iloc[:,2:]
# Out:
#                                                2        3        4
# 0                                         1 Mask     None     None
# 1                                         1 Mask     None     None
# 2   Professional Protective Disposable Face Mask  10 Pack     None
# 3                                          Adult    Black   1 Mask
# 4                                        50 Pack     None     None
# 5                                         1 Mask     None     None
# 6                                       for Kids   1 Mask     None
# 7                                       25 Masks     None     None
# 8                                          Adult     Gray   1 Mask
# 9                                          Large   3 Pack     None
# 10                                      20 Masks     None     None
# 11                                         Adult      Dot  1 Count
# 12                                    24 Filters     None     None
# 13                                       Neutral   3 Pack     None
# 14                                        1 Mask     None     None
# 15                                       Leopard   3 Pack     None
# 16                                          Kids    Black   1 Mask
# 17                                        Medium   1 Mask     None
# 18                                       3 Masks     None     None
# 19                                         Large   1 Mask     None
# 20                                          Kids     Gray  1 Count
# 21                                          Grey      S-M   1 Mask
# 22                                         Blush   3 Pack     None
# 23                                       5 Count     None     None
# 24                                       50 Pack     None     None
# 25                                       50 Pack     None     None
# 26                                       50 Pack     None     None

# %%
prod_df.head()
# Out:
#    product_id                                       product_name  \
# 0      103205  Hwipure, Disposable KF94 ( N95 / KN95/ FFP2 ) ...
# 1      101774  HIGUARD, Disposable KF94 ( N95 / KN95/ FFP2 ) ...
# 2      101955  SunJoy, KN95, Professional Protective Disposab...
# 3      103838         Lozperi, Copper Mask, Adult, Black, 1 Mask
# 4      102734        Zidian, Disposable Protective Mask, 50 Pack
#
#    product_price price_currency       product_availability  \
# 0           2.95            AUD  http://schema.org/InStock
# 1           2.95            AUD  http://schema.org/InStock
# 2           8.86            AUD  http://schema.org/InStock
# 3           6.85            AUD  http://schema.org/InStock
# 4          15.35            AUD  http://schema.org/InStock
#
#                                          product_url  \
# 0  https://au.iherb.com/pr/Hwipure-Disposable-KF9...
# 1  https://au.iherb.com/pr/HIGUARD-Disposable-KF9...
# 2  https://au.iherb.com/pr/SunJoy-KN95-Profession...
# 3  https://au.iherb.com/pr/Lozperi-Copper-Mask-Ad...
# 4  https://au.iherb.com/pr/Zidian-Disposable-Prot...
#
#                                      source_url    Brand  \
# 0  https://au.iherb.com/c/protective-face-masks  Hwipure
# 1  https://au.iherb.com/c/protective-face-masks  HIGUARD
# 2  https://au.iherb.com/c/protective-face-masks   SunJoy
# 3  https://au.iherb.com/c/protective-face-masks  Lozperi
# 4  https://au.iherb.com/c/protective-face-masks   Zidian
#
#                                         Type
# 0  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
# 1  Disposable KF94 ( N95 / KN95/ FFP2 ) Mask
# 2                                       KN95
# 3                                Copper Mask
# 4                 Disposable Protective Mask

# %%
y = rev_df.productId.value_counts()
y[y.index[0]]
# Out:
# 658

# %%
brand_name = list()
brand_num = list()
for i in range(0,len(z.index)):
    brand_name.append(prod_df.iloc[prod_df[prod_df.product_id == z.index[i]].index[0]].Type)
    brand_num.append(z[z.index[i]])

# %%
plt.barh(brand_name,brand_num)
# Out:
# <BarContainer object of 27 artists>

# %%
prod_df.groupby(['Brand','Type']).first()
# Out:
#                                                           product_id  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      102522
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      101774
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      103205
# Kitsch         100% Cotton Reusable Face Masks                101692
#                100% Cotton Reuseable Face Masks               100237
# Kosette        Fashion Mask with Filter Pocket                104022
#                Nano Reusable Face Protection Mask              99830
#                PM 2.5 Replaceable Filter                      104023
# La Hauteur     Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      100837
# Landsberg      3 Ply Disposable Protective Face Mask          101029
# Lozperi        Copper Mask                                    103838
# Luseta Beauty  Disposable Protection Face Mask                100099
# Now Foods      Face Mask                                      102455
# One Fine Day   Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      100839
# Puritas        10 Days Mask                                   103743
# SunJoy         KN95                                           101955
# Tony Moly      CTT KN95 Respirator Mask                       100541
# YJ Corporation Disposable KF94 ( N95 / KN95/ FFP2 ) Mask      100840
# Zidian         Disposable Protective Mask                     102734
#
#                                                                                                product_name  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  Dr. Puri, Disposable KF94 ( N95 / KN95/ FFP2 )...
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  HIGUARD, Disposable KF94 ( N95 / KN95/ FFP2 ) ...
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  Hwipure, Disposable KF94 ( N95 / KN95/ FFP2 ) ...
# Kitsch         100% Cotton Reusable Face Masks            Kitsch, 100% Cotton Reusable Face Masks, Neutr...
#                100% Cotton Reuseable Face Masks           Kitsch, 100% Cotton Reuseable Face Masks, Leop...
# Kosette        Fashion Mask with Filter Pocket            Kosette, Fashion Mask with Filter Pocket,  3 M...
#                Nano Reusable Face Protection Mask         Kosette, Nano Reusable Face Protection Mask, M...
#                PM 2.5 Replaceable Filter                     Kosette, PM 2.5 Replaceable Filter, 24 Filters
# La Hauteur     Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  La Hauteur, Disposable KF94 ( N95 / KN95/ FFP2...
# Landsberg      3 Ply Disposable Protective Face Mask      Landsberg, 3 Ply Disposable Protective Face Ma...
# Lozperi        Copper Mask                                       Lozperi, Copper Mask, Adult, Black, 1 Mask
# Luseta Beauty  Disposable Protection Face Mask            Luseta Beauty, Disposable Protection Face Mask...
# Now Foods      Face Mask                                            Now Foods, Face Mask, Grey, S-M, 1 Mask
# One Fine Day   Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  One Fine Day, Disposable KF94 ( N95 / KN95/ FF...
# Puritas        10 Days Mask                                            Puritas, 10 Days Mask, Large, 3 Pack
# SunJoy         KN95                                       SunJoy, KN95, Professional Protective Disposab...
# Tony Moly      CTT KN95 Respirator Mask                        Tony Moly, CTT KN95 Respirator Mask, 5 Count
# YJ Corporation Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  YJ Corporation, Disposable KF94 ( N95 / KN95/ ...
# Zidian         Disposable Protective Mask                       Zidian, Disposable Protective Mask, 50 Pack
#
#                                                           product_price  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask          47.24
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask           2.95
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask           2.95
# Kitsch         100% Cotton Reusable Face Masks                    17.72
#                100% Cotton Reuseable Face Masks                   17.72
# Kosette        Fashion Mask with Filter Pocket                    11.81
#                Nano Reusable Face Protection Mask                 22.44
#                PM 2.5 Replaceable Filter                           5.91
# La Hauteur     Disposable KF94 ( N95 / KN95/ FFP2 ) Mask           5.61
# Landsberg      3 Ply Disposable Protective Face Mask              36.54
# Lozperi        Copper Mask                                         6.85
# Luseta Beauty  Disposable Protection Face Mask                    49.61
# Now Foods      Face Mask                                           2.95
# One Fine Day   Disposable KF94 ( N95 / KN95/ FFP2 ) Mask           4.49
# Puritas        10 Days Mask                                        6.61
# SunJoy         KN95                                                8.86
# Tony Moly      CTT KN95 Respirator Mask                           26.57
# YJ Corporation Disposable KF94 ( N95 / KN95/ FFP2 ) Mask           3.93
# Zidian         Disposable Protective Mask                         15.35
#
#                                                          price_currency  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# Kitsch         100% Cotton Reusable Face Masks                      AUD
#                100% Cotton Reuseable Face Masks                     AUD
# Kosette        Fashion Mask with Filter Pocket                      AUD
#                Nano Reusable Face Protection Mask                   AUD
#                PM 2.5 Replaceable Filter                            AUD
# La Hauteur     Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# Landsberg      3 Ply Disposable Protective Face Mask                AUD
# Lozperi        Copper Mask                                          AUD
# Luseta Beauty  Disposable Protection Face Mask                      AUD
# Now Foods      Face Mask                                            AUD
# One Fine Day   Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# Puritas        10 Days Mask                                         AUD
# SunJoy         KN95                                                 AUD
# Tony Moly      CTT KN95 Respirator Mask                             AUD
# YJ Corporation Disposable KF94 ( N95 / KN95/ FFP2 ) Mask            AUD
# Zidian         Disposable Protective Mask                           AUD
#
#                                                                product_availability  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# Kitsch         100% Cotton Reusable Face Masks            http://schema.org/InStock
#                100% Cotton Reuseable Face Masks           http://schema.org/InStock
# Kosette        Fashion Mask with Filter Pocket            http://schema.org/InStock
#                Nano Reusable Face Protection Mask         http://schema.org/InStock
#                PM 2.5 Replaceable Filter                  http://schema.org/InStock
# La Hauteur     Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# Landsberg      3 Ply Disposable Protective Face Mask      http://schema.org/InStock
# Lozperi        Copper Mask                                http://schema.org/InStock
# Luseta Beauty  Disposable Protection Face Mask            http://schema.org/InStock
# Now Foods      Face Mask                                  http://schema.org/InStock
# One Fine Day   Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# Puritas        10 Days Mask                               http://schema.org/InStock
# SunJoy         KN95                                       http://schema.org/InStock
# Tony Moly      CTT KN95 Respirator Mask                   http://schema.org/InStock
# YJ Corporation Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  http://schema.org/InStock
# Zidian         Disposable Protective Mask                 http://schema.org/InStock
#
#                                                                                                 product_url  \
# Brand          Type
# Dr. Puri       Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  https://au.iherb.com/pr/Dr-Puri-Disposable-KF9...
# HIGUARD        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask  https://au.iherb.com/pr/HIGUARD-Disposable-KF9...
# Hwipure        Disposable KF94 ( N95 / KN95/ FFP2 ) Mask